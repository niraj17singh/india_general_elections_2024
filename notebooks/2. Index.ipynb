# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests

# URL of the HTML page
url = 'https://results.eci.gov.in/PcResultGenJune2024/index.htm'

# Send a GET request to the URL
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    # Get the HTML content
    html_content = response.text

prefix = "https://results.eci.gov.in/PcResultGenJune2024"
# Assuming you have the HTML content in a string variable `html_content`
soup = BeautifulSoup(html_content, 'html.parser')

# Find all <table> elements
tables = soup.find_all('table')

# Extract data from each table
dfs = []
for table in tables:
    rows = table.find_all('tr')
    data = []
    for row in rows:
        cols = row.find_all('td')
        for col in cols:
            if "href" in str(col):
                url = str(col).split("href=")[1].split(">")[0].strip("'").strip()
        row_data = [col.text.strip() for col in cols]
        row_data.append(prefix + "/" + url[1:-1])
        data.append(row_data)
    df = pd.DataFrame(data)
    dfs.append(df)

# Combine all DataFrames into one
combined_df = pd.concat(dfs, ignore_index=True)

# %%
col_name = ["Party", "Won", "Leading", "Total", "URL"]

# %%
combined_df.columns = col_name
combined_df = combined_df[combined_df["Total"].notna()]
combined_df["Won"] = combined_df["Won"].astype(int)
combined_df["Leading"] = combined_df["Leading"].astype(int)
combined_df["Total"] = combined_df["Total"].astype(int)
combined_df
# Out:
#                                                 Party  Won  Leading  Total  \
# 1                        Bharatiya Janata Party - BJP    1      237    238
# 2                      Indian National Congress - INC    0       99     99
# 3                                Samajwadi Party - SP    0       36     36
# 4                 All India Trinamool Congress - AITC    0       30     30
# 5                     Dravida Munnetra Kazhagam - DMK    0       21     21
# 6                                  Telugu Desam - TDP    0       16     16
# 7                        Janata Dal  (United) - JD(U)    0       15     15
# 8      Shiv Sena (Uddhav Balasaheb Thackrey) - SHSUBT    0       11     11
# 9   Nationalist Congress Party – Sharadchandra Paw...    0        8      8
# 10             Lok Janshakti Party(Ram Vilas) - LJPRV    0        5      5
# 11                                    Shiv Sena - SHS    0        5      5
# 12      Yuvajana Sramika Rythu Congress Party - YSRCP    0        4      4
# 13       Communist Party of India  (Marxist) - CPI(M)    0        4      4
# 14                         Rashtriya Janata Dal - RJD    0        3      3
# 15                  Indian Union Muslim League - IUML    0        3      3
# 16                             Aam Aadmi Party - AAAP    0        3      3
# 17                       Jharkhand Mukti Morcha - JMM    0        3      3
# 18                               Janasena Party - JnP    0        2      2
# 19  Communist Party of India  (Marxist-Leninist)  ...    0        2      2
# 20                      Janata Dal  (Secular) - JD(S)    0        2      2
# 21               Viduthalai Chiruthaigal Katchi - VCK    0        2      2
# 22                     Communist Party of India - CPI    0        2      2
# 23                            Rashtriya Lok Dal - RLD    0        2      2
# 24          Jammu & Kashmir National Conference - JKN    0        2      2
# 25              United People’s Party, Liberal - UPPL    0        1      1
# 26                           Asom Gana Parishad - AGP    0        1      1
# 27            Hindustani Awam Morcha (Secular) - HAMS    0        1      1
# 28                              Kerala Congress - KEC    0        1      1
# 29                Revolutionary Socialist Party - RSP    0        1      1
# 30                   Nationalist Congress Party - NCP    0        1      1
# 31                  Voice of the People Party - VOTPP    0        1      1
# 32                      Zoram People’s Movement - ZPM    0        1      1
# 33                              Biju Janata Dal - BJD    0        1      1
# 34                          Shiromani Akali Dal - SAD    0        1      1
': 'https://results.eci.gov.in/PcResultGenJune2024/partywiseleadresultState-369.htm',
#  'Indian National Congress - INC': 'https://results.eci.gov.in/PcResultGenJune2024/partywiseleadresultState-742.htm',
#  'Samajwadi Party - SP': 'https://results.eci.gov.in/PcResultGenJune2024/partywiseleadresultState-1680.htm',
#  'All India Trinamool Congress - AITC': 'https://results.eci.gov.in/PcResultGenJune2024/partywiseleadresultState-140.htm',
#  'Dravida Munnetra Kazhagam - DMK': 'https://results.eci.gov.in/PcResultGenJune2024/partywiseleadresultState-582.htm',
#  'Telugu Desam - TDP': 'https://results.eci.gov.in/PcResultGenJune2024/partywiseleadresultState-1745.htm',
#  'Janata Dal  (United) - JD(U)': 'https://results.eci.gov.in/PcResultGenJune2024/partywiseleadresultState-805.htm',
#  'Shiv Sena (Uddhav Balasaheb Thackrey) - SHSUBT': 'https://results.eci.gov.in/PcResultGenJune2024/partywiseleadresultState-3369.htm',
#  'Nationalist Congress Party – Sharadchandra Pawar - NCPSP': 'https://results.eci.gov.in/PcResultGenJune2024/partywiseleadresultState-3620.htm',
#  'Lok Janshakti Party(Ram Vilas) - LJPRV': 'https://results.eci.gov.in/PcResultGenJune2024/partywiseleadresultState-3165.htm',
#  'Shiv Sena - SHS': 'https://results.eci.gov.in/PcResultGenJune2024/partywiseleadresultState-3529.htm',
#  'Yuvajana Sramika Rythu Congress Party - YSRCP': 'https://results.eci.gov.in/PcResultGenJune2024/partywiseleadresultState-1888.htm',
#  'Communist Party of India  (Marxist) - CPI(M)': 'https://results.eci.gov.in/PcResultGenJune2024/partywiseleadresultState-547.htm',
#  'Rashtriya Janata Dal - RJD': 'https://results.eci.gov.in/PcResultGenJune2024/partywiseleadresultState-1420.htm',
#  'Indian Union Muslim League - IUML': 'https://results.eci.gov.in/PcResultGenJune2024/partywiseleadresultState-772.htm',
#  'Aam Aadmi Party - AAAP': 'https://results.eci.gov.in/PcResultGenJune2024/partywiseleadresultState-1.htm',
#  'Jharkhand Mukti Morcha - JMM': 'https://results.eci.gov.in/PcResultGenJune2024/partywiseleadresultState-852.htm',
#  'Janasena Party - JnP': 'https://results.eci.gov.in/PcResultGenJune2024/partywiseleadresultState-860.htm',
#  'Communist Party of India  (Marxist-Leninist)  (Liberation) - CPI(ML)(L)': 'https://results.eci.gov.in/PcResultGenJune2024/partywiseleadresultState-545.htm',
#  'Janata Dal  (Secular) - JD(S)': 'https://results.eci.gov.in/PcResultGenJune2024/partywiseleadresultState-804.htm',
#  'Viduthalai Chiruthaigal Katchi - VCK': 'https://results.eci.gov.in/PcResultGenJune2024/partywiseleadresultState-1847.htm',
#  'Communist Party of India - CPI': 'https://results.eci.gov.in/PcResultGenJune2024/partywiseleadresultState-544.htm',
#  'Rashtriya Lok Dal - RLD': 'https://results.eci.gov.in/PcResultGenJune2024/partywiseleadresultState-1458.htm',
#  'Jammu & Kashmir National Conference - JKN': 'https://results.eci.gov.in/PcResultGenJune2024/partywiseleadresultState-834.htm',
#  'United People’s Party, Liberal - UPPL': 'https://results.eci.gov.in/PcResultGenJune2024/partywiseleadresultState-1998.htm',
#  'Asom Gana Parishad - AGP': 'https://results.eci.gov.in/PcResultGenJune2024/partywiseleadresultState-83.htm',
#  'Hindustani Awam Morcha (Secular) - HAMS': 'https://results.eci.gov.in/PcResultGenJune2024/partywiseleadresultState-664.htm',
#  'Kerala Congress - KEC': 'https://results.eci.gov.in/PcResultGenJune2024/partywiseleadresultState-911.htm',
#  'Revolutionary Socialist Party - RSP': 'https://results.eci.gov.in/PcResultGenJune2024/partywiseleadresultState-1534.htm',
#  'Nationalist Congress Party - NCP': 'https://results.eci.gov.in/PcResultGenJune2024/partywiseleadresultState-1142.htm',
#  'Voice of the People Party - VOTPP': 'https://results.eci.gov.in/PcResultGenJune2024/partywiseleadresultState-3388.htm',
#  'Zoram People’s Movement - ZPM': 'https://results.eci.gov.in/PcResultGenJune2024/partywiseleadresultState-2757.htm',
#  'Biju Janata Dal - BJD': 'https://results.eci.gov.in/PcResultGenJune2024/partywiseleadresultState-350.htm',
#  'Shiromani Akali Dal - SAD': 'https://results.eci.gov.in/PcResultGenJune2024/partywiseleadresultState-1584.htm',
#  'Rashtriya Loktantrik Party - RLTP': 'https://results.eci.gov.in/PcResultGenJune2024/partywiseleadresultState-2484.htm',
#  'Bharat Adivasi Party - BHRTADVSIP': 'https://results.eci.gov.in/PcResultGenJune2024/partywiseleadresultState-3482.htm',
#  'Sikkim Krantikari Morcha - SKM': 'https://results.eci.gov.in/PcResultGenJune2024/partywiseleadresultState-1658.htm',
#  'Pattali Makkal Katchi - PMK': 'https://results.eci.gov.in/PcResultGenJune2024/partywiseleadresultState-1272.htm',
#  'Marumalarchi Dravida Munnetra Kazhagam - MDMK': 'https://results.eci.gov.in/PcResultGenJune2024/partywiseleadresultState-1046.htm',
#  'Aazad Samaj Party (Kanshi Ram) - ASPKR': 'https://results.eci.gov.in/PcResultGenJune2024/partywiseleadresultState-2989.htm',
#  'Apna Dal (Soneylal) - ADAL': 'https://results.eci.gov.in/PcResultGenJune2024/partywiseleadresultState-2070.htm',
#  'AJSU Party - AJSUP': 'https://results.eci.gov.in/PcResultGenJune2024/partywiseleadresultState-160.htm',
#  'All India Majlis-E-Ittehadul Muslimeen - AIMIM': 'https://results.eci.gov.in/PcResultGenJune2024/partywiseleadresultState-118.htm',
#  'Independent - IND': 'https://results.eci.gov.in/PcResultGenJune2024/partywiseleadresultState-743.htm'}

# %%
# # Export the dict as a json file
# import json
# with open("../data/party_url.json", "w") as outfile:
#     json.dump(party_url, outfile)
